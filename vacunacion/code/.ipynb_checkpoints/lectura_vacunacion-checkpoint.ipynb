# %% [markdown]
# ## Lectura del fichero de estado de vacunación publicado por Sanidad en
# * https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov/vacunaCovid19.htm

# %%
# importamos pandas, numpy y datetime
# previamente ha sido necesatio instalar el motor odfpy con un pip3 install odfpy
import pandas as pd
import numpy as np
from datetime import datetime,timedelta

# %% [markdown]
# Version branch cambios 18 enero

# %% [markdown]
# preparamos nombre del fichero csv, dentro del directorio csv. Preparamos dos ficheros:
#   * `estado_vacunacion_.csv` , última versión del mismo con el acumulado de todos los informes publicados
#   * `estado_vacunacion_yearmonthday.csv`, con la versión del día en cuestión, solo con la información de ese día

# %%
path_directorio='/Users/mharias/documents/proyectos/covid/vacunacion/csv/'
nombre_root_fichero = 'estado_vacunacion_{}'
fecha_informe = datetime.today()
#en el caso de queramos bajar otra fecha diferente a 'hoy'
#fecha_informe = datetime(year=2021,month=2,day=19)
fecha_informe_str=fecha_informe.strftime('%Y%m%d') #fecha formateada para nombre fichero
fecha_informe_pandas = fecha_informe.strftime('%-d/%-m/%y') #idem para el campo pandas
nombre_fichero_con_fecha = path_directorio + nombre_root_fichero.format(fecha_informe_str)
nombre_fichero_acumulado = path_directorio + nombre_root_fichero.format('')

# %% [markdown]
# Enlace al fichero en red en formato ods

# %%
enlace_bruto = 'https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov/documentos/Informe_Comunicacion_{}.ods'
enlace = enlace_bruto.format(fecha_informe_str)

# %% [markdown]
# Leemos el fichero

# %%
try:
    datos_row = pd.read_excel(enlace)
    print ('Ok, descargado {}'.format(enlace))
except:
    print ('No esta listo aun')
# Out:
# Ok, descargado https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov/documentos/Informe_Comunicacion_20210305.ods

# %% [markdown]
# Le echamos un vistazo para asegurar que ha ido todo bien

# %%
datos_row
# Out:
#             Unnamed: 0  Dosis entregadas Pfizer (1)  \
# 0            Andalucía                       739530
# 1               Aragón                       130185
# 2            Asturias                        128435
# 3             Baleares                        65880
# 4             Canarias                       148560
# 5            Cantabria                        62745
# 6     Castilla y Leon                        285195
# 7   Castilla La Mancha                       190575
# 8             Cataluña                       651140
# 9        C. Valenciana                       340660
# 10         Extremadura                       115325
# 11             Galicia                       222415
# 12            La Rioja                        31655
# 13              Madrid                       529935
# 14             Murcia                        134105
# 15             Navarra                        62745
# 16          País Vasco                       177660
# 17               Ceuta                         5490
# 18             Melilla                         4320
# 19             Totales                      4026555
#
#     Dosis entregadas Moderna (1)  Dosis entregadas AstraZeneca (1)  \
# 0                          73300                            208600
# 1                          12600                             32700
# 2                          12700                             25200
# 3                           6500                             28800
# 4                          14300                             53700
# 5                           5900                             14300
# 6                          27300                             59000
# 7                          18600                             50400
# 8                          63400                            191900
# 9                          31700                            124700
# 10                         10900                             26200
# 11                         19900                             66700
# 12                          2700                              7800
# 13                         51300                            167200
# 14                         13400                             37200
# 15                          5900                             16200
# 16                         16000                             54800
# 17                           600                              2200
# 18                           600                              2200
# 19                        387600                           1169800
#
#     Total Dosis entregadas (1)  Dosis administradas (2)  % sobre entregadas  \
# 0                      1021430                   878194            0.859769
# 1                       175485                   150631            0.858370
# 2                       166335                   128729            0.773914
# 3                       101180                    74598            0.737280
# 4                       216560                   167802            0.774852
# 5                        82945                    66555            0.802399
# 6                       371495                   293772            0.790783
# 7                       259575                   195716            0.753986
# 8                       906440                   734794            0.810637
# 9                       497060                   394016            0.792693
# 10                      152425                   125191            0.821329
# 11                      309015                   255614            0.827190
# 12                       42155                    33316            0.790321
# 13                      748435                   598738            0.799987
# 14                      184705                   137200            0.742806
# 15                       84845                    68249            0.804396
# 16                      248460                   155955            0.627687
# 17                        8290                     7104            0.856936
# 18                        7120                     5403            0.758848
# 19                     5583955                  4471577            0.800790
#
#     Nº Personas vacunadas(pauta completada)  \
# 0                                    244049
# 1                                     49532
# 2                                     43690
# 3                                     23934
# 4                                     54601
# 5                                     20759
# 6                                     97774
# 7                                     71960
# 8                                    192984
# 9                                    113075
# 10                                    43176
# 11                                    68562
# 12                                    10329
# 13                                   177916
# 14                                    51169
# 15                                    23670
# 16                                    52452
# 17                                     1577
# 18                                     1276
# 19                                  1342485
#
#    Fecha de la última vacuna registrada (2)
# 0                                2021-03-04
# 1                                2021-03-04
# 2                                2021-03-04
# 3                                2021-03-04
# 4                                2021-03-04
# 5                                2021-03-04
# 6                                2021-03-04
# 7                                2021-03-04
# 8                                2021-03-04
# 9                                2021-03-04
# 10                               2021-03-04
# 11                               2021-03-04
# 12                               2021-03-04
# 13                               2021-03-04
# 14                               2021-03-04
# 15                               2021-03-04
# 16                               2021-03-04
# 17                               2021-03-01
# 18                               2021-03-04
# 19                                      NaT

# %% [markdown]
# ..hacemos una copia para hacerle las transformaciones necesarias:

# %%
datos_hoy = datos_row.copy()

# %% [markdown]
# Primero renombramos columnas, añadimos luego una columna con la fecha del informe `date_pub`, y finalmente añadimos fuente y origen de datos para asegurar trazabilidad de los datos:

# %%
datos_hoy.columns=['ccaa','Dosis entregadas Pfizer','Dosis entregadas Moderna','Dosis entregadas AstraZeneca','Dosis entregadas','Dosis administradas','% sobre entregadas','Total pauta completada','Fecha de la ultima vacuna registrada']

# %%
datos_hoy['date_pub']=fecha_informe_pandas
datos_hoy['source_name']='Ministerio de Sanidad'
datos_hoy['source'] = enlace

# %% [markdown]
# vamos a convertir el formato de `Fecha de la ultima vacuna registrada` para que aparezca como día/mes/año sin añadir ceros de pad..de ahi el signo menos en el caso de dia y mes (%-d/%-m). La excepción se añade para la línea de Totales, que no lleva fecha asociada:

# %%
def convierte(x):
    campo =  x['Fecha de la ultima vacuna registrada']
    try:
        fecha = campo.strftime('%-d/%-m/%y')
        return fecha
    except:
        return campo

# %%
datos_hoy['Fecha de la ultima vacuna registrada'] = datos_hoy.apply(convierte,axis=1)

# %% [markdown]
# ..y ordenamos..

# %%
datos_hoy
# Out:
#                   ccaa  Dosis entregadas Pfizer  Dosis entregadas Moderna  \
# 0            Andalucía                   739530                     73300
# 1               Aragón                   130185                     12600
# 2            Asturias                    128435                     12700
# 3             Baleares                    65880                      6500
# 4             Canarias                   148560                     14300
# 5            Cantabria                    62745                      5900
# 6     Castilla y Leon                    285195                     27300
# 7   Castilla La Mancha                   190575                     18600
# 8             Cataluña                   651140                     63400
# 9        C. Valenciana                   340660                     31700
# 10         Extremadura                   115325                     10900
# 11             Galicia                   222415                     19900
# 12            La Rioja                    31655                      2700
# 13              Madrid                   529935                     51300
# 14             Murcia                    134105                     13400
# 15             Navarra                    62745                      5900
# 16          País Vasco                   177660                     16000
# 17               Ceuta                     5490                       600
# 18             Melilla                     4320                       600
# 19             Totales                  4026555                    387600
#
#     Dosis entregadas AstraZeneca  Dosis entregadas  Dosis administradas  \
# 0                         208600           1021430               878194
# 1                          32700            175485               150631
# 2                          25200            166335               128729
# 3                          28800            101180                74598
# 4                          53700            216560               167802
# 5                          14300             82945                66555
# 6                          59000            371495               293772
# 7                          50400            259575               195716
# 8                         191900            906440               734794
# 9                         124700            497060               394016
# 10                         26200            152425               125191
# 11                         66700            309015               255614
# 12                          7800             42155                33316
# 13                        167200            748435               598738
# 14                         37200            184705               137200
# 15                         16200             84845                68249
# 16                         54800            248460               155955
# 17                          2200              8290                 7104
# 18                          2200              7120                 5403
# 19                       1169800           5583955              4471577
#
#     % sobre entregadas  Total pauta completada  \
# 0             0.859769                  244049
# 1             0.858370                   49532
# 2             0.773914                   43690
# 3             0.737280                   23934
# 4             0.774852                   54601
# 5             0.802399                   20759
# 6             0.790783                   97774
# 7             0.753986                   71960
# 8             0.810637                  192984
# 9             0.792693                  113075
# 10            0.821329                   43176
# 11            0.827190                   68562
# 12            0.790321                   10329
# 13            0.799987                  177916
# 14            0.742806                   51169
# 15            0.804396                   23670
# 16            0.627687                   52452
# 17            0.856936                    1577
# 18            0.758848                    1276
# 19            0.800790                 1342485
#
#    Fecha de la ultima vacuna registrada date_pub            source_name  \
# 0                                4/3/21   5/3/21  Ministerio de Sanidad
# 1                                4/3/21   5/3/21  Ministerio de Sanidad
# 2                                4/3/21   5/3/21  Ministerio de Sanidad
# 3                                4/3/21   5/3/21  Ministerio de Sanidad
# 4                                4/3/21   5/3/21  Ministerio de Sanidad
# 5                                4/3/21   5/3/21  Ministerio de Sanidad
# 6                                4/3/21   5/3/21  Ministerio de Sanidad
# 7                                4/3/21   5/3/21  Ministerio de Sanidad
# 8                                4/3/21   5/3/21  Ministerio de Sanidad
# 9                                4/3/21   5/3/21  Ministerio de Sanidad
# 10                               4/3/21   5/3/21  Ministerio de Sanidad
# 11                               4/3/21   5/3/21  Ministerio de Sanidad
# 12                               4/3/21   5/3/21  Ministerio de Sanidad
# 13                               4/3/21   5/3/21  Ministerio de Sanidad
# 14                               4/3/21   5/3/21  Ministerio de Sanidad
# 15                               4/3/21   5/3/21  Ministerio de Sanidad
# 16                               4/3/21   5/3/21  Ministerio de Sanidad
# 17                               1/3/21   5/3/21  Ministerio de Sanidad
# 18                               4/3/21   5/3/21  Ministerio de Sanidad
# 19                                  NaT   5/3/21  Ministerio de Sanidad
#
#                                                source
# 0   https://www.mscbs.gob.es/profesionales/saludPu...
# 1   https://www.mscbs.gob.es/profesionales/saludPu...
# 2   https://www.mscbs.gob.es/profesionales/saludPu...
# 3   https://www.mscbs.gob.es/profesionales/saludPu...
# 4   https://www.mscbs.gob.es/profesionales/saludPu...
# 5   https://www.mscbs.gob.es/profesionales/saludPu...
# 6   https://www.mscbs.gob.es/profesionales/saludPu...
# 7   https://www.mscbs.gob.es/profesionales/saludPu...
# 8   https://www.mscbs.gob.es/profesionales/saludPu...
# 9   https://www.mscbs.gob.es/profesionales/saludPu...
# 10  https://www.mscbs.gob.es/profesionales/saludPu...
# 11  https://www.mscbs.gob.es/profesionales/saludPu...
# 12  https://www.mscbs.gob.es/profesionales/saludPu...
# 13  https://www.mscbs.gob.es/profesionales/saludPu...
# 14  https://www.mscbs.gob.es/profesionales/saludPu...
# 15  https://www.mscbs.gob.es/profesionales/saludPu...
# 16  https://www.mscbs.gob.es/profesionales/saludPu...
# 17  https://www.mscbs.gob.es/profesionales/saludPu...
# 18  https://www.mscbs.gob.es/profesionales/saludPu...
# 19  https://www.mscbs.gob.es/profesionales/saludPu...

# %%
datos_hoy=datos_hoy[['date_pub','ccaa','Dosis entregadas Pfizer',
                    'Dosis entregadas Moderna','Dosis entregadas AstraZeneca','Dosis entregadas',
                    'Dosis administradas','% sobre entregadas',
                    'Total pauta completada',
                    'Fecha de la ultima vacuna registrada','source_name','source']]

# %% [markdown]
# Hemos visto algún informe en el que se añaden espacios al nombre de Comunidad, nos aseguramos aquí de eliminarlos en caso de que vuelvan a aparecer:

# %%
datos_hoy['ccaa'] = datos_hoy['ccaa'].apply(lambda x : x.rstrip().lstrip())

# %%
datos_hoy['ccaa'].unique()
# Out:
# array(['Andalucía', 'Aragón', 'Asturias', 'Baleares', 'Canarias',
#        'Cantabria', 'Castilla y Leon', 'Castilla La Mancha', 'Cataluña',
#        'C. Valenciana', 'Extremadura', 'Galicia', 'La Rioja', 'Madrid',
#        'Murcia', 'Navarra', 'País Vasco', 'Ceuta', 'Melilla', 'Totales'],
#       dtype=object)

# %%
datos_hoy
# Out:
#    date_pub                ccaa  Dosis entregadas Pfizer  \
# 0    5/3/21           Andalucía                   739530
# 1    5/3/21              Aragón                   130185
# 2    5/3/21            Asturias                   128435
# 3    5/3/21            Baleares                    65880
# 4    5/3/21            Canarias                   148560
# 5    5/3/21           Cantabria                    62745
# 6    5/3/21     Castilla y Leon                   285195
# 7    5/3/21  Castilla La Mancha                   190575
# 8    5/3/21            Cataluña                   651140
# 9    5/3/21       C. Valenciana                   340660
# 10   5/3/21         Extremadura                   115325
# 11   5/3/21             Galicia                   222415
# 12   5/3/21            La Rioja                    31655
# 13   5/3/21              Madrid                   529935
# 14   5/3/21              Murcia                   134105
# 15   5/3/21             Navarra                    62745
# 16   5/3/21          País Vasco                   177660
# 17   5/3/21               Ceuta                     5490
# 18   5/3/21             Melilla                     4320
# 19   5/3/21             Totales                  4026555
#
#     Dosis entregadas Moderna  Dosis entregadas AstraZeneca  Dosis entregadas  \
# 0                      73300                        208600           1021430
# 1                      12600                         32700            175485
# 2                      12700                         25200            166335
# 3                       6500                         28800            101180
# 4                      14300                         53700            216560
# 5                       5900                         14300             82945
# 6                      27300                         59000            371495
# 7                      18600                         50400            259575
# 8                      63400                        191900            906440
# 9                      31700                        124700            497060
# 10                     10900                         26200            152425
# 11                     19900                         66700            309015
# 12                      2700                          7800             42155
# 13                     51300                        167200            748435
# 14                     13400                         37200            184705
# 15                      5900                         16200             84845
# 16                     16000                         54800            248460
# 17                       600                          2200              8290
# 18                       600                          2200              7120
# 19                    387600                       1169800           5583955
#
#     Dosis administradas  % sobre entregadas  Total pauta completada  \
# 0                878194            0.859769                  244049
# 1                150631            0.858370                   49532
# 2                128729            0.773914                   43690
# 3                 74598            0.737280                   23934
# 4                167802            0.774852                   54601
# 5                 66555            0.802399                   20759
# 6                293772            0.790783                   97774
# 7                195716            0.753986                   71960
# 8                734794            0.810637                  192984
# 9                394016            0.792693                  113075
# 10               125191            0.821329                   43176
# 11               255614            0.827190                   68562
# 12                33316            0.790321                   10329
# 13               598738            0.799987                  177916
# 14               137200            0.742806                   51169
# 15                68249            0.804396                   23670
# 16               155955            0.627687                   52452
# 17                 7104            0.856936                    1577
# 18                 5403            0.758848                    1276
# 19              4471577            0.800790                 1342485
#
#    Fecha de la ultima vacuna registrada            source_name  \
# 0                                4/3/21  Ministerio de Sanidad
# 1                                4/3/21  Ministerio de Sanidad
# 2                                4/3/21  Ministerio de Sanidad
# 3                                4/3/21  Ministerio de Sanidad
# 4                                4/3/21  Ministerio de Sanidad
# 5                                4/3/21  Ministerio de Sanidad
# 6                                4/3/21  Ministerio de Sanidad
# 7                                4/3/21  Ministerio de Sanidad
# 8                                4/3/21  Ministerio de Sanidad
# 9                                4/3/21  Ministerio de Sanidad
# 10                               4/3/21  Ministerio de Sanidad
# 11                               4/3/21  Ministerio de Sanidad
# 12                               4/3/21  Ministerio de Sanidad
# 13                               4/3/21  Ministerio de Sanidad
# 14                               4/3/21  Ministerio de Sanidad
# 15                               4/3/21  Ministerio de Sanidad
# 16                               4/3/21  Ministerio de Sanidad
# 17                               1/3/21  Ministerio de Sanidad
# 18                               4/3/21  Ministerio de Sanidad
# 19                                  NaT  Ministerio de Sanidad
#
#                                                source
# 0   https://www.mscbs.gob.es/profesionales/saludPu...
# 1   https://www.mscbs.gob.es/profesionales/saludPu...
# 2   https://www.mscbs.gob.es/profesionales/saludPu...
# 3   https://www.mscbs.gob.es/profesionales/saludPu...
# 4   https://www.mscbs.gob.es/profesionales/saludPu...
# 5   https://www.mscbs.gob.es/profesionales/saludPu...
# 6   https://www.mscbs.gob.es/profesionales/saludPu...
# 7   https://www.mscbs.gob.es/profesionales/saludPu...
# 8   https://www.mscbs.gob.es/profesionales/saludPu...
# 9   https://www.mscbs.gob.es/profesionales/saludPu...
# 10  https://www.mscbs.gob.es/profesionales/saludPu...
# 11  https://www.mscbs.gob.es/profesionales/saludPu...
# 12  https://www.mscbs.gob.es/profesionales/saludPu...
# 13  https://www.mscbs.gob.es/profesionales/saludPu...
# 14  https://www.mscbs.gob.es/profesionales/saludPu...
# 15  https://www.mscbs.gob.es/profesionales/saludPu...
# 16  https://www.mscbs.gob.es/profesionales/saludPu...
# 17  https://www.mscbs.gob.es/profesionales/saludPu...
# 18  https://www.mscbs.gob.es/profesionales/saludPu...
# 19  https://www.mscbs.gob.es/profesionales/saludPu...

# %% [markdown]
# guardamos el fichero de hoy en el directorio csv

# %%
datos_hoy.to_csv(nombre_fichero_con_fecha+'.csv',index = False)

# %% [markdown]
# y ahora bajamos el acumulado actual para añadirle los datos de hoy, y volverlo a subir

# %%
datos_acumulados = pd.read_csv(nombre_fichero_acumulado+'.csv')

# %%
datos_acumulados
# Out:
#     date_pub        ccaa  Dosis entregadas Pfizer  Dosis entregadas Moderna  \
# 0     4/1/21   Andalucía                      NaN                       NaN
# 1     4/1/21      Aragón                      NaN                       NaN
# 2     4/1/21    Asturias                      NaN                       NaN
# 3     4/1/21    Baleares                      NaN                       NaN
# 4     4/1/21    Canarias                      NaN                       NaN
# ..       ...         ...                      ...                       ...
# 855   4/3/21     Navarra                  62745.0                    5900.0
# 856   4/3/21  País Vasco                 177660.0                   16000.0
# 857   4/3/21       Ceuta                   5490.0                     600.0
# 858   4/3/21     Melilla                   4320.0                     600.0
# 859   4/3/21     Totales                4026555.0                  387600.0
#
#      Dosis entregadas AstraZeneca  Dosis entregadas  Dosis administradas  \
# 0                             NaN            140295                25809
# 1                             NaN             23715                 2004
# 2                             NaN             23720                 9380
# 3                             NaN              8940                  153
# 4                             NaN             20835                 4846
# ..                            ...               ...                  ...
# 855                       16200.0             84845                66248
# 856                       54800.0            248460               144966
# 857                        2200.0              8290                 6435
# 858                        2200.0              7120                 5228
# 859                     1169800.0           5583955              4229092
#
#      % sobre entregadas  Total pauta completada  \
# 0              0.183962                     NaN
# 1              0.084503                     NaN
# 2              0.395447                     NaN
# 3              0.017114                     NaN
# 4              0.232589                     NaN
# ..                  ...                     ...
# 855            0.780812                 22894.0
# 856            0.583458                 50194.0
# 857            0.776236                  1290.0
# 858            0.734270                  1276.0
# 859            0.757365               1308913.0
#
#     Última fecha de actualización de datos  \
# 0                                   3/1/21
# 1                                   2/1/21
# 2                                   3/1/21
# 3                                 28/12/20
# 4                                   3/1/21
# ..                                     ...
# 855                                    NaN
# 856                                    NaN
# 857                                    NaN
# 858                                    NaN
# 859                                    NaN
#
#     Fecha de la ultima vacuna registrada  \
# 0                                 3/1/21
# 1                                 2/1/21
# 2                                 3/1/21
# 3                               28/12/20
# 4                                 3/1/21
# ..                                   ...
# 855                               3/3/21
# 856                               3/3/21
# 857                               1/3/21
# 858                               3/3/21
# 859                                  NaN
#
#                                  source_name  \
# 0    Ministerio de Sanidad - Vacuna Covid 19
# 1    Ministerio de Sanidad - Vacuna Covid 20
# 2    Ministerio de Sanidad - Vacuna Covid 21
# 3    Ministerio de Sanidad - Vacuna Covid 22
# 4    Ministerio de Sanidad - Vacuna Covid 23
# ..                                       ...
# 855                    Ministerio de Sanidad
# 856                    Ministerio de Sanidad
# 857                    Ministerio de Sanidad
# 858                    Ministerio de Sanidad
# 859                    Ministerio de Sanidad
#
#                                                 source
# 0    https://www.mscbs.gob.es/profesionales/saludPu...
# 1    https://www.mscbs.gob.es/profesionales/saludPu...
# 2    https://www.mscbs.gob.es/profesionales/saludPu...
# 3    https://www.mscbs.gob.es/profesionales/saludPu...
# 4    https://www.mscbs.gob.es/profesionales/saludPu...
# ..                                                 ...
# 855  https://www.mscbs.gob.es/profesionales/saludPu...
# 856  https://www.mscbs.gob.es/profesionales/saludPu...
# 857  https://www.mscbs.gob.es/profesionales/saludPu...
# 858  https://www.mscbs.gob.es/profesionales/saludPu...
# 859  https://www.mscbs.gob.es/profesionales/saludPu...
#
# [860 rows x 13 columns]

# %% [markdown]
# concatenamos...

# %%
datos_acumulados=pd.concat([datos_acumulados,datos_hoy],ignore_index=True)

# %%
datos_acumulados.columns
# Out:
# Index(['date_pub', 'ccaa', 'Dosis entregadas Pfizer',
#        'Dosis entregadas Moderna', 'Dosis entregadas AstraZeneca',
#        'Dosis entregadas', 'Dosis administradas', '% sobre entregadas',
#        'Total pauta completada', 'Última fecha de actualización de datos',
#        'Fecha de la ultima vacuna registrada', 'source_name', 'source'],
#       dtype='object')

# %%
datos_acumulados = datos_acumulados[['date_pub', 'ccaa','Dosis entregadas Pfizer','Dosis entregadas Moderna',
                                     'Dosis entregadas AstraZeneca',
                                     'Dosis entregadas', 'Dosis administradas','% sobre entregadas',
                                     'Total pauta completada','Última fecha de actualización de datos',
                                     'Fecha de la ultima vacuna registrada','source_name', 'source']]

# %%
datos_acumulados
# Out:
#     date_pub        ccaa  Dosis entregadas Pfizer  Dosis entregadas Moderna  \
# 0     4/1/21   Andalucía                      NaN                       NaN
# 1     4/1/21      Aragón                      NaN                       NaN
# 2     4/1/21    Asturias                      NaN                       NaN
# 3     4/1/21    Baleares                      NaN                       NaN
# 4     4/1/21    Canarias                      NaN                       NaN
# ..       ...         ...                      ...                       ...
# 875   5/3/21     Navarra                  62745.0                    5900.0
# 876   5/3/21  País Vasco                 177660.0                   16000.0
# 877   5/3/21       Ceuta                   5490.0                     600.0
# 878   5/3/21     Melilla                   4320.0                     600.0
# 879   5/3/21     Totales                4026555.0                  387600.0
#
#      Dosis entregadas AstraZeneca  Dosis entregadas  Dosis administradas  \
# 0                             NaN            140295                25809
# 1                             NaN             23715                 2004
# 2                             NaN             23720                 9380
# 3                             NaN              8940                  153
# 4                             NaN             20835                 4846
# ..                            ...               ...                  ...
# 875                       16200.0             84845                68249
# 876                       54800.0            248460               155955
# 877                        2200.0              8290                 7104
# 878                        2200.0              7120                 5403
# 879                     1169800.0           5583955              4471577
#
#      % sobre entregadas  Total pauta completada  \
# 0              0.183962                     NaN
# 1              0.084503                     NaN
# 2              0.395447                     NaN
# 3              0.017114                     NaN
# 4              0.232589                     NaN
# ..                  ...                     ...
# 875            0.804396                 23670.0
# 876            0.627687                 52452.0
# 877            0.856936                  1577.0
# 878            0.758848                  1276.0
# 879            0.800790               1342485.0
#
#     Última fecha de actualización de datos  \
# 0                                   3/1/21
# 1                                   2/1/21
# 2                                   3/1/21
# 3                                 28/12/20
# 4                                   3/1/21
# ..                                     ...
# 875                                    NaN
# 876                                    NaN
# 877                                    NaN
# 878                                    NaN
# 879                                    NaN
#
#     Fecha de la ultima vacuna registrada  \
# 0                                 3/1/21
# 1                                 2/1/21
# 2                                 3/1/21
# 3                               28/12/20
# 4                                 3/1/21
# ..                                   ...
# 875                               4/3/21
# 876                               4/3/21
# 877                               1/3/21
# 878                               4/3/21
# 879                                  NaT
#
#                                  source_name  \
# 0    Ministerio de Sanidad - Vacuna Covid 19
# 1    Ministerio de Sanidad - Vacuna Covid 20
# 2    Ministerio de Sanidad - Vacuna Covid 21
# 3    Ministerio de Sanidad - Vacuna Covid 22
# 4    Ministerio de Sanidad - Vacuna Covid 23
# ..                                       ...
# 875                    Ministerio de Sanidad
# 876                    Ministerio de Sanidad
# 877                    Ministerio de Sanidad
# 878                    Ministerio de Sanidad
# 879                    Ministerio de Sanidad
#
#                                                 source
# 0    https://www.mscbs.gob.es/profesionales/saludPu...
# 1    https://www.mscbs.gob.es/profesionales/saludPu...
# 2    https://www.mscbs.gob.es/profesionales/saludPu...
# 3    https://www.mscbs.gob.es/profesionales/saludPu...
# 4    https://www.mscbs.gob.es/profesionales/saludPu...
# ..                                                 ...
# 875  https://www.mscbs.gob.es/profesionales/saludPu...
# 876  https://www.mscbs.gob.es/profesionales/saludPu...
# 877  https://www.mscbs.gob.es/profesionales/saludPu...
# 878  https://www.mscbs.gob.es/profesionales/saludPu...
# 879  https://www.mscbs.gob.es/profesionales/saludPu...
#
# [880 rows x 13 columns]

# %%
datos_acumulados['ccaa'].unique()
# Out:
# array(['Andalucía', 'Aragón', 'Asturias', 'Baleares', 'Canarias',
#        'Cantabria', 'Castilla y Leon', 'Castilla La Mancha', 'Cataluña',
#        'C. Valenciana', 'Extremadura', 'Galicia', 'La Rioja', 'Madrid',
#        'Murcia', 'Navarra', 'País Vasco', 'Ceuta', 'Melilla', 'Totales'],
#       dtype=object)

# %% [markdown]
# y volvemos a subirlo..

# %%
datos_acumulados.to_csv(nombre_fichero_acumulado+'.csv',index=False)
