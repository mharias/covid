# %%
import pandas as pd

import matplotlib.pyplot as plt

from matplotlib.ticker import FuncFormatter
from matplotlib import cm
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from matplotlib.dates import (YEARLY, MONTHLY, DateFormatter, MonthLocator,DayLocator,
                              rrulewrapper, RRuleLocator, drange)
import matplotlib.image as mpimg
from matplotlib.animation import FuncAnimation
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.colors as colors

import numpy as np
from datetime import datetime,timedelta
import seaborn as sns
# %matplotlib inline

import urllib.request

import matplotlib.image as mpimg
from matplotlib.animation import FuncAnimation
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox

# %%
enlace = 'https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov/documentos/Informe_Comunicacion_20210107.ods'

# %%
datos_row = pd.read_excel(enlace)

# %%
datos = datos_row.copy()

# %%
datos.columns=['Comunidad','dosis_entregadas','dosis_administradas','porcentaje_administradas','fecha']

# %%
datos=datos[['Comunidad','fecha','dosis_entregadas','dosis_administradas','porcentaje_administradas']]

# %%
datos
# Out:
#              Comunidad      fecha  dosis_entregadas  dosis_administradas  \
# 0            Andalucía 2021-01-06            140295                53934
# 1               Aragón 2021-01-06             23715                 6186
# 2            Asturias  2021-01-06             23720                14406
# 3             Baleares 2021-01-05             12840                 3190
# 4             Canarias 2021-01-06             27660                 7330
# 5            Cantabria 2021-01-07             11850                 1564
# 6     Castilla y Leon  2021-01-06             51390                22103
# 7   Castilla La Mancha 2021-01-06             35550                 7666
# 8             Cataluña 2021-01-06            120545                24515
# 9        C. Valenciana 2021-01-07             61225                11677
# 10         Extremadura 2021-01-05             21725                 3309
# 11             Galicia 2021-01-07             37555                20265
# ...

# %%
datos.to_csv('estado_vacunacion.csv')
