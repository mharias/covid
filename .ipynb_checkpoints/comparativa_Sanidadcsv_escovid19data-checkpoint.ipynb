# %% [markdown]
# # Descarga de datos de Fallecimientos desde Sanidad

# %% [markdown]
# ## Objetivo

# %% [markdown]
# Vamos a hacer una lectura de los fallecimientos comunicados por sanidad en cada uno de los pdf que publica

# %% [markdown]
# ## Código

# %% [markdown]
# Tenemos un montón de librerias con las que vamos a trabajar, no he tenido ningún problema en instalar aquellas no disponibles en el entorno Anaconda con el que trabajo por medio de `pip install libreria` realizado desde un terminal abierto desde el entorno `env`.

# %%
import os.path as pth
import datetime as dt
import time
from glob import glob
import re
import pandas as pd
import numpy as np

import requests
from shutil import copyfile

import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from matplotlib import cm
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from matplotlib.dates import (YEARLY, MONTHLY, DateFormatter, WeekdayLocator, MonthLocator,DayLocator,
                              rrulewrapper, RRuleLocator, drange)
import seaborn as sns
import matplotlib.colors as colors

import numpy as np
from datetime import datetime
import seaborn as sns
# %matplotlib inline

from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from io import StringIO

# %% [markdown]
# Preparamos las expresiones regulares que nos ayudarán en la interpretación de la información que sacamos de los pdf.

# %% [markdown]
# Definimos variables que nos ayuden en la gestión de los nombres de los ficheros.

# %%
codigo_comunidad={'ES-AN':'Andalucia', 'ES-AR':'Aragon', 'ES-AS':'Asturias', 
                  'ES-IB':'Baleares', 'ES-CN':'Canarias','ES-CB':'Cantabria',
                  'ES-CM':'Castilla La Mancha','ES-CL':'Castilla y Leon', 'ES-CT':'Cataluña', 
                  'ES-CE':'Ceuta', 'ES-VC':'C.Valenciana', 'ES-EX':'Extremadura', 
                  'ES-GA':'Galicia', 'ES-MD':'Madrid','ES-ML':'Melilla', 
                  'ES-MC':'Murcia', 'ES-NC':'Navarra', 'ES-PV':'Pais Vasco', 
                  'ES-RI':'La Rioja'}

# %%
datadir='datos_sanidad/'
path_escovid19data='https://github.com/montera34/escovid19data/blob/master/data/output/covid19-provincias-spain_consolidated.csv?raw=true'
path_sanidad_pdf='datos_sanidad.csv'
path_sanidad='https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov/documentos/Datos_Casos_COVID19.csv?raw=true'

# %%
columnas_escovid_interes=['date','ccaa', 'deceased','deceased_hosp_eus', 
       'daily_deaths', 'daily_deaths_hosp_eus', 'daily_deaths_inc',
       'daily_deaths_avg3', 'daily_deaths_avg7', 'daily_deaths_avg7_hosp_eus',
       'deaths_last_week']

# %%
escovid.columns
# Out:
# Index(['date', 'province', 'ine_code', 'ccaa', 'new_cases', 'PCR', 'TestAc',
#        'activos', 'hospitalized', 'intensive_care', 'deceased',
#        'cases_accumulated', 'cases_accumulated_PCR', 'recovered',
#        'deceased_hosp_eus', 'num_casos', 'num_casos_prueba_pcr',
#        'num_casos_prueba_test_ac', 'num_casos_prueba_otras',
#        'num_casos_prueba_desconocida', 'poblacion', 'cases_per_cienmil',
#        'intensive_care_per_1000000', 'deceassed_per_100000',
#        'hospitalized_per_100000', 'cases_14days', 'cases_7days',
#        'cases_PCR_14days', 'cases_PCR_7days', 'daily_cases',
#        'daily_cases_avg7', 'daily_cases_PCR', 'daily_cases_PCR_avg7',
#        'daily_deaths', 'daily_deaths_hosp_eus', 'daily_deaths_inc',
#        'daily_deaths_avg3', 'daily_deaths_avg7', 'daily_deaths_avg7_hosp_eus',
#        'deaths_last_week', 'num_casos_avg7', 'num_casos_prueba_pcr_avg7',
#        'ia14', 'source_name', 'source', 'comments'],
#       dtype='object')

# %% [markdown]
# # Descargamos el pdf de sanidad

# %%
sanidad_pdf=pd.read_csv(path_sanidad_pdf)

# %%
nombre_columnas=list(sanidad_pdf.columns)
nombre_columnas[0]='Fecha'
sanidad_pdf.columns=nombre_columnas

# %%
sanidad_pdf.set_index('Fecha',inplace=True)

# %%
sanidad_pdf=sanidad_pdf.T

# %%
sanidad_pdf.index
# Out:
# Index(['2020-04-16', '2020-04-17', '2020-04-18', '2020-04-19', '2020-04-20',
#        '2020-04-21', '2020-04-22', '2020-04-23', '2020-04-24', '2020-04-25',
#        ...
#        '2020-11-16', '2020-11-17', '2020-11-18', '2020-11-19', '2020-11-20',
#        '2020-11-23', '2020-11-24', '2020-11-25', '2020-11-26', '2020-11-27'],
#       dtype='object', length=184)

# %%
sanidad_pdf
# Out:
# Fecha       Andalucia  Aragon  Asturias  Baleares  Canarias  Cantabria  \
# 2020-04-16        912     543       168       131       107        137
# 2020-04-17        940     562       174       134       111        144
# 2020-04-18        967     601       187       148       115        149
# 2020-04-19        993     619       196       155       119        153
# 2020-04-20       1013     637       200       157       119        158
# ...               ...     ...       ...       ...       ...        ...
# 2020-11-23       3633    2189       857       398       326        297
# 2020-11-24       3725    2208       883       399       333        297
# 2020-11-25       3790    2227       904       402       334        298
# 2020-11-26       3842    2251       929       404       336        300
# 2020-11-27       3903    2279       954       404       339        304
#
# Fecha       Castilla La Mancha  Castilla y Leon  Cataluña  Ceuta  \
# 2020-04-16                1796             1372      3855      4
# 2020-04-17                1852             1401      3752      4
# 2020-04-18                1913             1429      3879      4
# 2020-04-19                1963             1458      3933      4
# 2020-04-20                2021             1493      4009      4
# ...                        ...              ...       ...    ...
# 2020-11-23                3687             4343      7596     49
# 2020-11-24                3693             4394      7692     51
# 2020-11-25                3722             4434      7793     52
# 2020-11-26                3738             4463      7850     52
# 2020-11-27                3761             4487      7911     54
#
# Fecha       C.Valenciana  Extremadura  Galicia  Madrid  Melilla  Murcia  \
# 2020-04-16           972          359      310    6877        2     111
# 2020-04-17           999          372      320    7007        2     112
# 2020-04-18          1042          380      334    7132        2     115
# 2020-04-19          1065          384      346    7239        2     116
# 2020-04-20          1079          389      352    7351        2     117
# ...                  ...          ...      ...     ...      ...     ...
# 2020-11-23          2188          895     1153   11211       36     555
# 2020-11-24          2237          902     1172   11250       37     566
# 2020-11-25          2262          909     1173   11279       38     583
# 2020-11-26          2288          915     1178   11349       39     589
# 2020-11-27          2298          928     1184   11352       40     597
#
# Fecha       Navarra  Pais Vasco  La Rioja
# 2020-04-16      261         956       257
# 2020-04-17      338         992       262
# 2020-04-18      354        1020       272
# 2020-04-19      369        1062       277
# 2020-04-20      385        1081       285
# ...             ...         ...       ...
# 2020-11-23      845        2343       530
# 2020-11-24      850        2446       533
# 2020-11-25      853        2447       537
# 2020-11-26      856        2452       543
# 2020-11-27      863        2467       543
#
# [184 rows x 19 columns]

# %% [markdown]
# # Descargamos escovid19data

# %%
datos_leidos = pd.read_csv(path_escovid19data)

# %%
datos_leidos
# Out:
#              date           province  ine_code                     ccaa  \
# 0      2020-01-01           Albacete         2     Castilla - La Mancha
# 1      2020-01-01   Alicante/Alacant         3     Comunitat Valenciana
# 2      2020-01-01            Almería         4                Andalucía
# 3      2020-01-01        Araba/Álava         1               País Vasco
# 4      2020-01-01           Asturias        33  Asturias, Principado de
# ...           ...                ...       ...                      ...
# 17230  2020-11-27            Sevilla        41                Andalucía
# 17231  2020-11-27              Soria        42          Castilla y León
# 17232  2020-11-27  Valencia/València        46     Comunitat Valenciana
# 17233  2020-11-27         Valladolid        47          Castilla y León
# 17234  2020-11-27             Zamora        49          Castilla y León
#
#        new_cases  PCR  TestAc  activos  hospitalized  intensive_care  ...  \
# 0            NaN  NaN     NaN      NaN           NaN             NaN  ...
# 1            NaN  NaN     NaN      NaN           NaN             NaN  ...
# 2            NaN  NaN     NaN      NaN           NaN             NaN  ...
# 3            NaN  NaN     NaN      NaN           NaN             NaN  ...
# 4            NaN  NaN     NaN      NaN           NaN             NaN  ...
# ...          ...  ...     ...      ...           ...             ...  ...
# 17230        NaN  NaN     NaN      NaN           NaN             NaN  ...
# 17231       28.0  NaN     NaN      NaN          30.0             5.0  ...
# 17232      769.0  NaN     NaN      NaN         621.0           159.0  ...
# 17233      195.0  NaN     NaN      NaN         224.0            73.0  ...
# 17234       59.0  NaN     NaN      NaN          97.0            14.0  ...
#
#        daily_deaths_avg3  daily_deaths_avg7  daily_deaths_avg7_hosp_eus  \
# 0                    NaN                NaN                         NaN
# 1                    NaN                NaN                         NaN
# 2                    NaN                NaN                         NaN
# 3                    NaN                NaN                         NaN
# 4                    NaN                NaN                         NaN
# ...                  ...                ...                         ...
# 17230               13.3               14.0                         NaN
# 17231                0.7                0.4                         NaN
# 17232               10.0               10.7                         NaN
# 17233                4.3                4.9                         NaN
# 17234                4.0                3.0                         NaN
#
#        deaths_last_week  num_casos_avg7  num_casos_prueba_pcr_avg7   ia14  \
# 0                     0             NaN                        NaN    NaN
# 1                     0             NaN                        NaN    NaN
# 2                     0             NaN                        NaN    NaN
# 3                     0             NaN                        NaN    NaN
# 4                     0             NaN                        NaN    NaN
# ...                 ...             ...                        ...    ...
# 17230                98             NaN                        NaN  435.8
# 17231                 3             NaN                        NaN  620.5
# 17232                72             NaN                        NaN  390.9
# 17233                34             NaN                        NaN  781.5
# 17234                21             NaN                        NaN  715.8
#
#                           source_name  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 17230              Junta de Andalucía
# 17231        Junta de Castilla y León
# 17232  Sanidad Generalitat Valenciana
# 17233        Junta de Castilla y León
# 17234        Junta de Castilla y León
#
#                                                   source  comments
# 0                                                    NaN       NaN
# 1                                                    NaN       NaN
# 2                                                    NaN       NaN
# 3                                                    NaN       NaN
# 4                                                    NaN       NaN
# ...                                                  ...       ...
# 17230  https://www.juntadeandalucia.es/institutodeest...       NaN
# 17231  https://analisis.datosabiertos.jcyl.es/explore...       NaN
# 17232  https://www.gva.es/es/inicio/area_de_prensa/no...       NaN
# 17233  https://analisis.datosabiertos.jcyl.es/explore...       NaN
# 17234  https://analisis.datosabiertos.jcyl.es/explore...       NaN
#
# [17235 rows x 46 columns]

# %%
columnas_escovid_interes
# Out:
# (['date',
#   'ccaa',
#   'deceased',
#   'deceased_hosp_eus',
#   'daily_deaths',
#   'daily_deaths_hosp_eus',
#   'daily_deaths_inc',
#   'daily_deaths_avg3',
#   'daily_deaths_avg7',
#   'daily_deaths_avg7_hosp_eus',
#   'deaths_last_week'],)

# %%
datos_leidos[columnas_escovid_interes]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-38fca1a923c5> in <module>
# ----> 1 datos_leidos[columnas_escovid_interes]
#
# /opt/anaconda3/envs/CoVid/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /opt/anaconda3/envs/CoVid/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2644                 )
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#    2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(['date', 'ccaa', 'deceased', 'deceased_hosp_eus', 'daily_deaths', 'daily_deaths_hosp_eus', 'daily_deaths_inc', 'daily_deaths_avg3', 'daily_deaths_avg7', 'daily_deaths_avg7_hosp_eus', 'deaths_last_week'],)' is an invalid key

# %%
escovid = escovid.groupby(['ccaa','date']).sum()
# Out:
#                       deceased  deceased_hosp_eus  daily_deaths  \
# ccaa      date
# Andalucía 2020-01-01       0.0                0.0           0.0
#           2020-01-02       0.0                0.0           0.0
#           2020-01-03       0.0                0.0           0.0
#           2020-01-04       0.0                0.0           0.0
#           2020-01-05       0.0                0.0           0.0
# ...                        ...                ...           ...
# Rioja, La 2020-11-23     530.0                0.0           3.0
#           2020-11-24     533.0                0.0           3.0
#           2020-11-25     537.0                0.0           4.0
#           2020-11-26     543.0                0.0           6.0
#           2020-11-27     543.0                0.0           0.0
#
#                       daily_deaths_hosp_eus  daily_deaths_inc  \
# ccaa      date
# Andalucía 2020-01-01                    0.0               0.0
#           2020-01-02                    0.0               0.0
#           2020-01-03                    0.0               0.0
#           2020-01-04                    0.0               0.0
#           2020-01-05                    0.0               0.0
# ...                                     ...               ...
# Rioja, La 2020-11-23                    0.0               0.6
#           2020-11-24                    0.0               0.6
#           2020-11-25                    0.0               0.8
#           2020-11-26                    0.0               1.1
#           2020-11-27                    0.0               0.0
#
#                       daily_deaths_avg3  daily_deaths_avg7  \
# ccaa      date
# Andalucía 2020-01-01                0.0                0.0
#           2020-01-02                0.0                0.0
#           2020-01-03                0.0                0.0
#           2020-01-04                0.0                0.0
#           2020-01-05                0.0                0.0
# ...                                 ...                ...
# Rioja, La 2020-11-23                0.0                2.9
#           2020-11-24                2.3                2.6
#           2020-11-25                3.3                2.8
#           2020-11-26                4.3                3.1
#           2020-11-27                3.3                2.8
#
#                       daily_deaths_avg7_hosp_eus  deaths_last_week
# ccaa      date
# Andalucía 2020-01-01                         0.0                 0
#           2020-01-02                         0.0                 0
#           2020-01-03                         0.0                 0
#           2020-01-04                         0.0                 0
#           2020-01-05                         0.0                 0
# ...                                          ...               ...
# Rioja, La 2020-11-23                         0.0                16
#           2020-11-24                         0.0                16
#           2020-11-25                         0.0                16
#           2020-11-26                         0.0                20
#           2020-11-27                         0.0                17
#
# [6295 rows x 9 columns]

# %%
# Out:
# array(['Castilla - La Mancha', 'Comunitat Valenciana', 'Andalucía',
#        'País Vasco', 'Asturias, Principado de', 'Castilla y León',
#        'Extremadura', 'Balears, Illes', 'Cataluña', 'Cantabria', 'Ceuta',
#        'Galicia', 'Aragón', 'Madrid, Comunidad de', 'Melilla',
#        'Murcia, Región de', 'Navarra, Comunidad Foral de', 'Canarias',
#        'Rioja, La'], dtype=object)

# %%
dif=(sanidad_pdf-sanidad_csv)

# %%
#dif.reset_index(inplace=True)

# %%
dif

# %%
dif.loc['2020-05-05','Madrid']

# %%
dif=dif.stack().reset_index()

# %%
dif.columns=['Fecha','Comunidad','Fallecidos']

# %%
dif

# %%
import seaborn as sns

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x='Fecha', y="Fallecidos",
             hue="Comunidad",
             data=dif)

# %%
titulo='Comparativa sanidad: pdf diario original - CSV actual'
pal = sns.cubehelix_palette(52, rot=-.25, light=.7)
with sns.plotting_context('paper',font_scale=1.3):
    g = sns.FacetGrid(dif,col='Comunidad', hue='Comunidad',col_wrap=4,aspect=2.5, sharex=True,
                        margin_titles=False,height=2, 
                        sharey=False,palette=pal)


def grafica(x, color, label):
    ax1 = plt.gca()
    
    ax1.text(0.5, .8, label[0:15], fontweight="bold", color='navy',
            ha="center", va="center", size=18,transform=ax1.transAxes)
    sns.lineplot(dif.loc[dif['Comunidad']==label,'Fecha'], dif.loc[dif['Comunidad']==label,'Fallecidos'],color='navy',alpha=.6,ax=ax1)
    #ax1.set_xlim(-1,7)
    ax1.set_ylim(min(0,dif.loc[dif['Comunidad']==label,'Fallecidos'].min()),max(0,dif.loc[dif['Comunidad']==label,'Fallecidos'].max()*1.5))
    #    #ax1.set_yticks(ax1.get_yticks()[1:-2])
    ax1.yaxis.set_tick_params(labelsize=16,labelcolor='navy',width=10,rotation=0) 
    ax1.xaxis.set_tick_params(labelsize=16,labelcolor='navy',width=0,rotation=60) 
    #ax1.xaxis.set_major_formatter(plt.FuncFormatter(lambda v,x:'{:.1f}{}'.format(v/escala[0],escala[1])))
    XmajorFmt = DateFormatter('%b')
    ax1.xaxis.set_major_formatter(XmajorFmt)
    ax1.axhline(y=0,color='red')       
g.map(grafica,'Comunidad')


g.fig.subplots_adjust(hspace=0)

g.set_titles("")
    
g.despine(bottom=True, left=True)
#g.fig.suptitle('{}'.format(titulo),fontsize=26,color='navy')
g.fig.suptitle(titulo,
                fontsize=40)
g.fig.subplots_adjust(top=.9,wspace=0.25,hspace=.2)   
    
plt.savefig('graficos/comparativa_sanidad_pdf_csv',dpi=144)  
plt.show()
